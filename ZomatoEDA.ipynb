# %% [markdown]
# ## Zomato
#
# This notebook is an analysis on Zomato's Bangalore Restaurant Dataset

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
#pd.set_option('display.height', 500)
pd.set_option('display.max_rows', 500)
import plotly  
import plotly.plotly as py
import plotly.graph_objs as go
import plotly.figure_factory as ff

# %%
plotly.tools.set_credentials_file(username='ishivaji', api_key='6GObDR9EMP03GbqAzKQG')

# %%
# %matplotlib inline

# %%
plotly.__version__
# Out:
# u'3.8.1'

# %%
trace0 = go.Scatter(
    x=[1, 2, 3, 4],
    y=[10, 15, 13, 17]
)
trace1 = go.Scatter(
    x=[1, 2, 3, 4],
    y=[16, 5, 11, 9]
)
data = [trace0, trace1]

py.iplot(data, filename = 'basic-line', auto_open=True)
# Out:
# High five! You successfully sent some data to your account on plotly. View your plot in your browser at https://plot.ly/~ishivaji/0 or inside your plot.ly account where it is named 'basic-line'
# /anaconda3/lib/python3.7/site-packages/IPython/core/display.py:689: UserWarning:
#
# Consider using IPython.display.IFrame instead
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~ishivaji/0.embed" height="525px" width="100%"></iframe>

# %%
df = pd.read_csv("https://raw.githubusercontent.com/plotly/datasets/master/school_earnings.csv")

data = [go.Bar(x=df.School,
            y=df.Gap)]

py.iplot(data)
# Out:
# ---------------------------------------------------------------------------
# URLError                                  Traceback (most recent call last)
# <ipython-input-5-2ce1ab300a40> in <module>()
# ----> 1 df = pd.read_csv("https://raw.githubusercontent.com/plotly/datasets/master/school_earnings.csv")
#       2
#       3 data = [go.Bar(x=df.School,
#       4             y=df.Gap)]
#       5
#
# ...

# %%
trace_women = go.Bar(x=df.School,
                  y=df.Women,
                  name='Women',
                  marker=dict(color='#ffcdd2'))

trace_men = go.Bar(x=df.School,
                y=df.Men,
                name='Men',
                marker=dict(color='#A2D5F2'))
'''
trace_gap = go.Bar(x=df.School,
                y=df.Gap,
                name='Gap',
                marker=dict(color='#59606D'))
'''
data = [trace_women, trace_men]

layout = go.Layout(title="Average Earnings for Graduates",
                xaxis=dict(title='School'),
                yaxis=dict(title='Salary (in thousands)'))

fig = go.Figure(data=data, layout=layout)

py.iplot(fig)
# Out:
# /anaconda3/lib/python3.7/site-packages/IPython/core/display.py:689: UserWarning:
#
# Consider using IPython.display.IFrame instead
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~ishivaji/24.embed" height="525px" width="100%"></iframe>

# %%
import plotly.figure_factory as ff
fips = ['06021', '06023', '06027',
        '06029', '06033', '06059',
        '06047', '06049', '06051',
        '06055', '06061']
values = range(len(fips))

fig = ff.create_choropleth(fips=fips, values=values)
# Out:
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:6692: FutureWarning:
#
# Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.

# %%
mapbox_access_token = "pk.eyJ1Ijoibm9uYW1lbWFwYm94IiwiYSI6ImNqeHl2bDdmbDAxMGUza3E4cTBsazc2YjAifQ.a3OfHKC_d0b_E-dXY0q6pg"
data = [
    go.Scattermapbox(
        lat=['45.5017'],
        lon=['-73.5673'],
        mode='markers',
        marker=go.scattermapbox.Marker(
            size=14
        ),
        text=['Montreal'],
    )
]

layout = go.Layout(
    autosize=True,
    hovermode='closest',
    mapbox=go.layout.Mapbox(
        accesstoken=mapbox_access_token,
        bearing=0,
        center=go.layout.mapbox.Center(
            lat=45,
            lon=-73
        ),
        pitch=0,
        zoom=5
    ),
)

fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='Montreal Mapbox')
# Out:
# /anaconda3/lib/python3.7/site-packages/IPython/core/display.py:689: UserWarning:
#
# Consider using IPython.display.IFrame instead
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~ishivaji/20.embed" height="525px" width="100%"></iframe>

# %%
# !ls ../datasets/
# Out:
# zomato.csv

# %%
zom_df = pd.read_csv("../datasets/zomato.csv")

# %%
zom_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51717 entries, 0 to 51716
# Data columns (total 17 columns):
# url                            51717 non-null object
# address                        51717 non-null object
# name                           51717 non-null object
# online_order                   51717 non-null object
# book_table                     51717 non-null object
# rate                           43942 non-null object
# votes                          51717 non-null int64
# phone                          50509 non-null object
# location                       51696 non-null object
# rest_type                      51490 non-null object
# dish_liked                     23639 non-null object
# cuisines                       51672 non-null object
# approx_cost(for two people)    51371 non-null object
# reviews_list                   51717 non-null object
# menu_item                      51717 non-null object
# listed_in(type)                51717 non-null object
# ...

# %%
zom_df.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes                             phone  \
# 0          Yes        Yes  4.1/5    775    080 42297555\r\n+91 9743772233
# ...

# %%
#zom_df.groupby(["location","rate"]).count()
zom_df[zom_df["location"] == "Whitefield"].sort_values(["rate"], ascending="False")
# Out:
#                                                      url  \
# 6929   https://www.zomato.com/bangalore/imperia-resta...
# 8241   https://www.zomato.com/bangalore/imperia-resta...
# 51157  https://www.zomato.com/bangalore/a2b-adyar-ana...
# 50207  https://www.zomato.com/bangalore/imperia-resta...
# 51310  https://www.zomato.com/bangalore/imperia-resta...
# 51711  https://www.zomato.com/bangalore/bhagini-2-whi...
# 51677  https://www.zomato.com/bangalore/bhagini-2-whi...
# 51476  https://www.zomato.com/bangalore/ammis-biryani...
# 50648  https://www.zomato.com/bangalore/ammis-biryani...
# 51458  https://www.zomato.com/bangalore/we-foodie-whi...
# 50824  https://www.zomato.com/bangalore/southern-spic...
# 50647  https://www.zomato.com/bangalore/mast-kalandar...
# 50911  https://www.zomato.com/bangalore/crunch-pizzas...
# 51503  https://www.zomato.com/bangalore/crunch-pizzas...
# 51247  https://www.zomato.com/bangalore/mast-kalandar...
# ...

# %%
count_df = zom_df.groupby(["location"])["url"].count()

# %%
count_df.sort_values(ascending=False)
# Out:
# location
# BTM                              5124
# HSR                              2523
# Koramangala 5th Block            2504
# JP Nagar                         2235
# Whitefield                       2144
# Indiranagar                      2083
# Jayanagar                        1926
# Marathahalli                     1846
# Bannerghatta Road                1630
# Bellandur                        1286
# Electronic City                  1258
# Koramangala 1st Block            1238
# Brigade Road                     1218
# Koramangala 7th Block            1181
# Koramangala 6th Block            1156
# Sarjapur Road                    1065
# Ulsoor                           1023
# Koramangala 4th Block            1017
# MG Road                           918
# Banashankari                      906
# Kalyan Nagar                      853
# Richmond Road                     812
# Frazer Town                       727
# Malleshwaram                      725
# ...

# %%
zom_df= zom_df.dropna()
zom_df["price_index"] = pd.to_numeric(zom_df["approx_cost(for two people)"].apply(lambda x: x.replace(",","")))
#zom_df.sort_values(["approx_cost(for two people)"], ascending=False)
white_df = zom_df[zom_df["location"] == "Whitefield"]
white_df_list = zom_df[["name","price_index","location","votes","cuisines"]].sort_values(["votes"], ascending=False)
white_df_list["name"].unique()[:10]
# Out:
# array(['Byg Brewski Brewing Company', 'Toit', 'Truffles',
#        "AB's - Absolute Barbecues", 'The Black Pearl', 'Big Pitcher',
#        'Onesta', 'Arbor Brewing Company', 'Empire Restaurant',
#        'Prost Brew Pub'], dtype=object)

# %%
zom_df.groupby(["name"])["url"].count().sort_values(ascending=False).head(50)
# Out:
# name
# Onesta                       85
# Empire Restaurant            69
# KFC                          59
# McDonald's                   57
# Pizza Hut                    56
# Domino's Pizza               55
# Smally's Resto Cafe          54
# Faasos                       54
# Corner House Ice Cream       52
# Burger King                  51
# Polar Bear                   48
# Smoor                        47
# Mani's Dum Biryani           47
# Hammered                     47
# Pizza Stop                   46
# Mainland China               45
# Subway                       45
# Chung Wah                    45
# Lakeview Milkbar             44
# Truffles                     43
# Beijing Bites                43
# Leon Grill                   42
# Petoo                        42
# Oye Amritsar                 41
# Chai Point                   41
# Krispy Kreme                 41
# Natural Ice Cream            40
# Toscano                      40
# California Burrito           39
# ...

# %%
white_df[["name","votes","location","cuisines","rest_type"]].sort_values(["votes"], ascending=False)
# Out:
#                                                     name  votes    location  \
# 51649                                         Biergarten   7064  Whitefield
# 51685                                         Biergarten   7064  Whitefield
# 51038                                         Biergarten   7064  Whitefield
# 8248                                          Biergarten   6876  Whitefield
# 7885                                          Biergarten   6865  Whitefield
# 51039                               Windmills Craftworks   5954  Whitefield
# 51686                               Windmills Craftworks   5954  Whitefield
# 51650                               Windmills Craftworks   5954  Whitefield
# 8249                                Windmills Craftworks   5892  Whitefield
# 7886                                Windmills Craftworks   5890  Whitefield
# 51071                       Chili's American Grill & Bar   4957  Whitefield
# ...

# %%
white_df[["name","votes"]].sort_values(["votes"], ascending=False).head(50)
# Out:
#                                          name  votes
# 51649                              Biergarten   7064
# 51685                              Biergarten   7064
# 51038                              Biergarten   7064
# 8248                               Biergarten   6876
# 7885                               Biergarten   6865
# 51039                    Windmills Craftworks   5954
# 51686                    Windmills Craftworks   5954
# 51650                    Windmills Craftworks   5954
# 8249                     Windmills Craftworks   5892
# 7886                     Windmills Craftworks   5890
# 51071            Chili's American Grill & Bar   4957
# 50271            Chili's American Grill & Bar   4955
# 50543                           Kapoor's Cafe   3021
# 51068                           Kapoor's Cafe   3021
# 51041               AB's - Absolute Barbecues   3009
# 51042                                Flechazo   3004
# 7895                            Kapoor's Cafe   2992
# ...

# %%
_df["cuisines"].str.split(",",expand=True).T
# Out:
#           0              1         2              3             4      \
# 0  North Indian        Chinese      Cafe   South Indian  North Indian
# 1       Mughlai   North Indian   Mexican   North Indian    Rajasthani
# 2       Chinese           Thai   Italian           None          None
# 3          None           None      None           None          None
# 4          None           None      None           None          None
# 5          None           None      None           None          None
# 6          None           None      None           None          None
# 7          None           None      None           None          None
#
#           5         7             8           9     10     ...          51700  \
# 0  North Indian     Pizza          Cafe        Cafe  Cafe  ...    Continental
# 1          None      Cafe       Italian     Mexican  None  ...   North Indian
# 2          None   Italian   Continental     Italian  None  ...        Italian
# ...

# %%
zom_df.groupby(["cuisines"])["name"].count().sort_values(ascending=False).head(50)
# Out:
# cuisines
# North Indian                                        1144
# North Indian, Chinese                                777
# South Indian                                         359
# Cafe                                                 273
# South Indian, North Indian, Chinese                  233
# Bakery, Desserts                                     215
# Desserts, Beverages                                  214
# Chinese                                              210
# Ice Cream, Desserts                                  208
# Desserts                                             206
# Biryani                                              169
# Chinese, Momos                                       162
# Finger Food                                          151
# Fast Food                                            150
# North Indian, Chinese, Biryani                       139
# Mithai, Street Food                                  138
# ...

# %%
zom_df_ni = zom_df[zom_df["cuisines"] == "North Indian"][["name","price_index","location", "rate"]].sort_values("price_index", ascending=False)

# %%
zom_df["rating"] =(zom_df["rate"].apply(lambda x:  x.split("/")[0] ))

# %%
zom_df = zom_df[zom_df["rating"] != "NEW"]

# %%
zom_df["rating"] = pd.to_numeric(zom_df["rating"])

# %%
zom_df_ni = zom_df_ni.drop_duplicates()

# %%
zom_df_ni
# Out:
#                                          name  price_index  \
# 43348                Riwaz - The Ritz-Carlton         4000
# 12677                Riwaz - The Ritz-Carlton         4000
# 40278    Dum Pukht Jolly Nabobs - ITC Windsor         4000
# 39356                Riwaz - The Ritz-Carlton         4000
# 48586        Indian Durbar - Conrad Bengaluru         3000
# 39392             Ssaffron - Shangri-La Hotel         3000
# 15616        Indian Durbar - Conrad Bengaluru         3000
# 12604                                 Tandoor         2100
# 43174                                 Tandoor         2100
# 19133        Tiger Trail - Royal Orchid Hotel         2000
# 45616        Tiger Trail - Royal Orchid Hotel         2000
# 7118                             Punjab Grill         2000
# 51048                            Punjab Grill         2000
# 11570            Northern Gate- Gateway Hotel         1900
# 37699            Northern Gate- Gateway Hotel         1900
# ...

# %%
zom_df_raing_ni = zom_df[zom_df["cuisines"] == "North Indian"].groupby("name").agg({"rating":["mean"]})

# %%
zom_df_raing_ni.columns = zom_df_raing_ni.columns.droplevel(0)

# %%
zom_df_raing_ni = zom_df_raing_ni.sort_values(["mean"], ascending=False)

# %%
newdf = pd.merge(zom_df_ni, zom_df_raing_ni, on="name")

# %%
newdf =newdf[["name", "price_index", "location","mean"]].drop_duplicates()

# %%
newdf = newdf.sort_values(["mean", "price_index"], ascending=False)

# %%
newdf["price"] = pd.to_numeric(newdf["price_index"])

# %%
newdf[newdf["price"] > 1000]
# Out:
#                                       name  price_index  \
# 11                            Punjab Grill         2000
# 31                           Delhi Highway         1200
# 6              Ssaffron - Shangri-La Hotel         3000
# 28  Salt - Indian Restaurant - Bar & Grill         1500
# 40                 Dhaba - Estd 1986 Delhi         1100
# 47                   Dhaba Estd 1986 Delhi         1100
# 24                           Punjab Bistro         1500
# 26                           Punjab Bistro         1500
# 3     Dum Pukht Jolly Nabobs - ITC Windsor         4000
# 39              Barbecued - By The Orchard         1200
# 21                   Punjabi by Nature 2.0         1600
# 22                   Punjabi by Nature 2.0         1600
# 0                 Riwaz - The Ritz-Carlton         4000
# 9         Tiger Trail - Royal Orchid Hotel         2000
# 16     The Terrace at Windmills Craftworks         1800
# 43                           Punjabi Times         1100
# ...

# %%
zom_df[zom_df["name"] == "Rim Naam - The Oberoi"]
# Out:
#                                                      url  \
# 4983   https://www.zomato.com/bangalore/rim-naam-the-...
# 6053   https://www.zomato.com/bangalore/rim-naam-the-...
# 11547  https://www.zomato.com/bangalore/rim-naam-the-...
# 12572  https://www.zomato.com/bangalore/rim-naam-the-...
# 17550  https://www.zomato.com/bangalore/rim-naam-the-...
# 19118  https://www.zomato.com/bangalore/rim-naam-the-...
# 37674  https://www.zomato.com/bangalore/rim-naam-the-...
# 38625  https://www.zomato.com/bangalore/rim-naam-the-...
# 42165  https://www.zomato.com/bangalore/rim-naam-the-...
# 43180  https://www.zomato.com/bangalore/rim-naam-the-...
# 47226  https://www.zomato.com/bangalore/rim-naam-the-...
# 48175  https://www.zomato.com/bangalore/rim-naam-the-...
#
#                                      address                   name  \
# 4983   The Oberoi, 37-39, MG Road, Bangalore  Rim Naam - The Oberoi
# 6053   The Oberoi, 37-39, MG Road, Bangalore  Rim Naam - The Oberoi
# ...

# %%
zom_df[zom_df["name"] == "Punjab Grill"]["reviews_list"]
# Out:
# 7118     [('Rated 5.0', 'RATED\n  The food is great...t...
# 39559    [('Rated 5.0', 'RATED\n  One of the best place...
# 40095    [('Rated 5.0', 'RATED\n  One of the best place...
# 46253    [('Rated 5.0', 'RATED\n  Good food, great serv...
# 46960    [('Rated 5.0', 'RATED\n  Good food, great serv...
# 50266    [('Rated 5.0', 'RATED\n  This place is a must ...
# 51048    [('Rated 5.0', 'RATED\n  This place is a must ...
# Name: reviews_list, dtype: object

# %%
zom_df_raing_ni = zom_df[zom_df["cuisines"] == "North Indian"].groupby("name").agg({"rating":["mean"]})

# %%
np.argmax(zom_df["rest_type"].unique() == "Fine Dining")
# Out:
# 45

# %%
zom_df["rest_type"].unique()[45]
# Out:
# 'Fine Dining'

# %%
fine_df = zom_df[zom_df["rest_type"] == 'Fine Dining']

# %%
fine_df[fine_df["location"] == "Whitefield"].groupby("name").agg({"rating":["mean"]})
# Out:
#                                                       rating
#                                                         mean
# name
# Alto Vino - Bengaluru Marriott Hotel Whitefield     4.300000
# Feast - Sheraton Grand Bengaluru Whitefield Hot...  4.500000
# Incanto - The Zuri                                  4.000000
# Latitude Whitefield                                 3.900000
# M Cafe - Bengaluru Marriott Hotel Whitefield        4.100000
# Terracotta Whitefield                               4.000000
# Tiffin Room - Miraya Hotel & Residences             3.766667
# Whitefield Bar and Grill - Bengaluru Marriott H...  4.150000

# %%
zom_df[zom_df["name"] == "Punjab Grill"]
# Out:
#                                                      url  \
# 7118   https://www.zomato.com/bangalore/punjab-grill-...
# 39559  https://www.zomato.com/bangalore/punjab-grill-...
# 40095  https://www.zomato.com/bangalore/punjab-grill-...
# 46253  https://www.zomato.com/bangalore/punjab-grill-...
# 46960  https://www.zomato.com/bangalore/punjab-grill-...
# 50266  https://www.zomato.com/bangalore/punjab-grill-...
# 51048  https://www.zomato.com/bangalore/punjab-grill-...
#
#                                                  address          name  \
# 7118   Ground Floor, Forum Shantiniketan, Whitefield ...  Punjab Grill
# 39559  26/1, Dr Rajkumar Road, Brigade Gateway Campus...  Punjab Grill
# 40095  26/1, Dr Rajkumar Road, Brigade Gateway Campus...  Punjab Grill
# 46253  26/1, Dr Rajkumar Road, Brigade Gateway Campus...  Punjab Grill
# 46960  26/1, Dr Rajkumar Road, Brigade Gateway Campus...  Punjab Grill
# 50266  Ground Floor, Forum Shantiniketan, Whitefield ...  Punjab Grill
# ...
